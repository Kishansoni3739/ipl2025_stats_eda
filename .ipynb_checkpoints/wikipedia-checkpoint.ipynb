# %%
import requests
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = "https://en.wikipedia.org/wiki/2025_Indian_Premier_League"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 "
                  "(KHTML, like Gecko) Chrome/120.0 Safari/537.36"
}
response = requests.get(url, headers=headers)
print(response.status_code)
soup = BeautifulSoup(response.text, "html.parser")
data_records = []
print(soup.title.text)
# Out:
# 200
# 2025 Indian Premier League - Wikipedia

# %%
matches = soup.find_all("div", style="width: 100%; clear:both")

# %%
#Scrapper

for match in matches:
    tables = match.find_all("table")
    table1_data = tables[0].get_text("\n", strip=True).split("\n")
    match_no = table1_data[0]
    match_date = table1_data[1]
    match_date = match_date.replace("\xa0", " ")
    match_time = None
    
    for item in table1_data:
        if ":" in item:
            match_time = item.replace("(" , "").strip()
            break

    table2_data = tables[1].get_text("\n", strip=True).split("\n")
        
    if (len(table2_data) <= 4):
        team1 = table2_data[0]
        score1 = "0"
        team2 = table2_data[3]
        score2 = "0"
    else:
        team1 = table2_data[0]
        score1 = table2_data[2]
        team2 = table2_data[4]
        score2 = table2_data[5]
    
    table3_data = tables[2].get_text("\n", strip=True).split("\n")
    venue = table3_data[1]
    result = table3_data[0]
    winner = result.split(" won")[0]
    if len(table3_data) == 7:
        pom = "no result"
    else:
        pom = table3_data[len(table3_data) - 2]
    
    toss_winner = "N/A"
    toss_desicion = "N/A"
    for li in match.select("li"):
        text = li.get_text(strip=True)
        if "won the toss" in text:
            toss_winner = text.split(" won the toss")[0]
            toss_decision = text.split(" to ")[1]
            break
            
    #Data Records
    data_records.append({
        "match_no":match_no,
        "date":match_date,
        "time":match_time,
        "venue":venue,
        "toss_winner": toss_winner,
        "toss_decision":toss_decision,
        "team1":team1,
        "team2":team2,
        "team1_score":score1,
        "team2_score":score2,
        "winner":winner,
        "result":result,
        "POM":pom
    }) 
    #print(team2)

# %%
df = pd.DataFrame(data_records)

# %%
df.tail()
# Out:
#        match_no         date   time  \
# 69     Match 70  27 May 2025  19:30
# 70  Qualifier 1  29 May 2025  19:30
# 71   Eliminator  30 May 2025  19:30
# 72  Qualifier 2  1 June 2025  19:30
# 73        Final  3 June 2025  19:30
#
#                                                 venue  \
# 69                              Ekana Cricket Stadium
# 70  Maharaja Yadavindra Singh International Cricke...
# 71  Maharaja Yadavindra Singh International Cricke...
# 72                              Narendra Modi Stadium
# 73                              Narendra Modi Stadium
#
#                     toss_winner toss_decision                        team1  \
# 69  Royal Challengers Bengaluru        field.         Lucknow Super Giants
# 70  Royal Challengers Bengaluru        field.                 Punjab Kings
# 71               Mumbai Indians          bat.               Mumbai Indians
# 72                 Punjab Kings        field.               Mumbai Indians
# 73                 Punjab Kings        field.  Royal Challengers Bengaluru
#
#                           team2       team1_score         team2_score  \
# 69  Royal Challengers Bengaluru  227/3 (20 overs)  230/4 (18.4 overs)
# 70             106/2 (10 overs)                 v      Marcus Stoinis
# 71             208/6 (20 overs)                 v        Rohit Sharma
# 72             207/5 (19 overs)                 v    Suryakumar Yadav
# 73             184/7 (20 overs)                 v         Virat Kohli
#
#                          winner                                        result  \
# 69  Royal Challengers Bengaluru  Royal Challengers Bengaluru won by 6 wickets
# 70  Royal Challengers Bengaluru  Royal Challengers Bengaluru won by 8 wickets
# 71               Mumbai Indians                 Mumbai Indians won by 20 runs
# 72                 Punjab Kings                 Punjab Kings won by 5 wickets
# 73  Royal Challengers Bengaluru     Royal Challengers Bengaluru won by 6 runs
#
#               POM
# 69  Jitesh Sharma
# 70  Suyash Sharma
# 71   Rohit Sharma
# 72   Shreyas Iyer
# 73  Krunal Pandya

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   match_no       74 non-null     object
#  1   date           74 non-null     object
#  2   time           74 non-null     object
#  3   venue          74 non-null     object
#  4   toss_winner    74 non-null     object
#  5   toss_decision  74 non-null     object
#  6   team1          74 non-null     object
#  7   team2          74 non-null     object
#  8   team1_score    74 non-null     object
#  9   team2_score    74 non-null     object
#  10  winner         74 non-null     object
#  11  result         74 non-null     object
#  12  POM            74 non-null     object
# dtypes: object(13)
# memory usage: 7.6+ KB

# %%
df.isnull().sum()
# Out:
# match_no         0
# date             0
# time             0
# venue            0
# toss_winner      0
# toss_decision    0
# team1            0
# team2            0
# team1_score      0
# team2_score      0
# winner           0
# result           0
# POM              0
# dtype: int64
